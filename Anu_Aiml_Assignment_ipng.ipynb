# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushamohanbabu/Anushamohanbabu/blob/main/Anu_Aiml_Assignment_ipng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_name = "Anusha"
student_class = "3rd year btech"
student_id  = "3320"
#student_list of subjects learned
student_subjects ="python,java,sql"
#student marks gained
student_marks = {1:'89',2:'95',3:'99'}
student_email_id ="anumohan@gmail.com"
student_ph_no ="987654321"
student_Address ="13-19-14 vinayaka nagar, tirupati"
student_list ={
        "ID": "3321",
        "Name": "Ravi",
        "Age": 21,
        "Branch": "ECE",
        "Marks": [78, 82, 80]
}
print(student_name)
print(student_class)
print(student_id)
print(student_subjects)
print(student_marks)
print(student_email_id)
print(student_ph_no)
print(student_Address)
print(student_list)
# Out:
# Anusha
# 3rd year btech
# 3320
# python,java,sql
# {1: '89', 2: '95', 3: '99'}
# anumohan@gmail.com
# 987654321
# 13-19-14 vinayaka nagar, tirupati
# {'ID': '3321', 'Name': 'Ravi', 'Age': 21, 'Branch': 'ECE', 'Marks': [78, 82, 80]}
